# %% [markdown]
# **Name** :- **Anjali Srivastava**
#
# **Task 2 of OASIS INFOBYTE**
#
# **Data Science Internship **

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv("/content/Unemployment in India.csv")
data1.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
data1.tail()
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 763    NaN   NaN        NaN                               NaN
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 763                  NaN                                       NaN  NaN
# 764                  NaN                                       NaN  NaN
# 765                  NaN                                       NaN  NaN
# 766                  NaN                                       NaN  NaN
# 767                  NaN                                       NaN  NaN

# %%
data2 = pd.read_csv("/content/Unemployment_Rate_upto_11_2020.csv")
data2.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# 1    15.9129     79.74
# 2    15.9129     79.74
# 3    15.9129     79.74
# 4    15.9129     79.74

# %%
data2.tail()
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 262  West Bengal   30-06-2020          M                              7.29
# 263  West Bengal   31-07-2020          M                              6.83
# 264  West Bengal   31-08-2020          M                             14.87
# 265  West Bengal   30-09-2020          M                              9.35
# 266  West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 262             30726310                                     40.39     East
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 262    22.9868    87.855
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# 266    22.9868    87.855

# %% [markdown]
# Checking the shape of data1 and data2

# %%
data1.shape
# Out:
# (768, 7)

# %%
data2.shape
# Out:
# (267, 9)

# %% [markdown]
# Checking the null values in data1 and data2

# %%
data1.isnull().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %% [markdown]
# Performing Operations on data2

# %%
data2.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# 25%                                   37.265000   18.112400   76.085600
# 50%                                   40.390000   23.610200   79.019300
# 75%                                   44.055000   27.278400   85.279900
# max                                   69.690000   33.778200   92.937600

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(5,5))
sns.heatmap(data2.corr(),annot=True)
plt.title("HEAT MAP")
plt.show()
# Out:
# <ipython-input-48-16999e71be1d>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# <ipython-input-48-16999e71be1d>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data2.corr(),annot=True)

# %%
data2.columns =["States","Date","Frequency","Estimated Unemployment Rate","Estimated Employed","Estimated Labour Participation Rate","Region","longitude","latitude"]
sns.histplot(x="Estimated Employed",hue = "Region",data=data2)
plt.title("employment")
plt.show()

# %%
plt.title("Unemployment")
data2.columns =["States","Date","Frequency","Estimated Unemployment Rate","Estimated Employed","Estimated Labour Participation Rate","Region","longitude","latitude"]
sns.histplot(x="Estimated Unemployment Rate",hue = "Region",data=data2)
plt.show()

# %%
 sns.pairplot(data2)

# %%
sns.boxplot(x="Estimated Employed",data=data2)
# Out:
# <Axes: xlabel='Estimated Employed'>

# %% [markdown]
# In the above box plot of Estimated Employer there are ouliers

# %%
sns.boxplot(x="Estimated Unemployment Rate",data=data2)
# Out:
# <Axes: xlabel='Estimated Unemployment Rate'>

# %% [markdown]
# In the above box plot of unemployment there are outliers

# %% [markdown]
# BarPlot Visualization

# %%
data2.columns =["States","Date","Frequency","Estimated Unemployment Rate","Estimated Employed","Estimated Labour Participation Rate","Region","longitude","latitude"]
sns.barplot(x="Estimated Unemployment Rate",y="latitude",data=data2)
# Out:
# <Axes: xlabel='Estimated Unemployment Rate', ylabel='latitude'>

# %%
data2.columns =["States","Date","Frequency","Estimated Unemployment Rate","Estimated Employed","Estimated Labour Participation Rate","Region","longitude","latitude"]
sns.barplot(x="Estimated Unemployment Rate",y="longitude",data=data2)
# Out:
# <Axes: xlabel='Estimated Unemployment Rate', ylabel='longitude'>

# %% [markdown]
# Line Plot Visualization

# %%
data2.columns =["States","Date","Frequency","Estimated Unemployment Rate","Estimated Employed","Estimated Labour Participation Rate","Region","longitude","latitude"]
sns.lineplot(x="Estimated Unemployment Rate",y="latitude",data=data2)
# Out:
# <Axes: xlabel='Estimated Unemployment Rate', ylabel='latitude'>

# %% [markdown]
# BarPlot Visualization taking x=Unemployment Rate and y=Region

# %%
data2.columns =["States","Date","Frequency","Estimated Unemployment Rate","Estimated Employed","Estimated Labour Participation Rate","Region","longitude","latitude"]
sns.barplot(x="Estimated Unemployment Rate",y="Region",data=data2)
# Out:
# <Axes: xlabel='Estimated Unemployment Rate', ylabel='Region'>

# %% [markdown]
# Line Plot taking columns Estimated Labour Participation and Region

# %%
data2.columns =["States","Date","Frequency","Estimated Unemployment Rate","Estimated Employed","Estimated Labour Participation Rate","Region","longitude","latitude"]
sns.lineplot(x="Estimated Labour Participation Rate",y="Region",data=data2)
# Out:
# <Axes: xlabel='Estimated Labour Participation Rate', ylabel='Region'>

# %% [markdown]
# Line Plot taking columns Estimated Labour Participation and Frequency

# %%
data2.columns =["States","Date","Frequency","Estimated Unemployment Rate","Estimated Employed","Estimated Labour Participation Rate","Region","longitude","latitude"]
sns.lineplot(x="Estimated Labour Participation Rate",y="Frequency",data=data2)
# Out:
# <Axes: xlabel='Estimated Labour Participation Rate', ylabel='Frequency'>

# %% [markdown]
# Line Plot taking columns Estimated Labour Participation and longitude

# %%
data2.columns =["States","Date","Frequency","Estimated Unemployment Rate","Estimated Employed","Estimated Labour Participation Rate","Region","longitude","latitude"]
sns.lineplot(x="Estimated Labour Participation Rate",y="longitude",data=data2)
# Out:
# <Axes: xlabel='Estimated Labour Participation Rate', ylabel='longitude'>

# %% [markdown]
# LinePlot taking columns Estimated Labour Participation and latitude

# %%
data2.columns =["States","Date","Frequency","Estimated Unemployment Rate","Estimated Employed","Estimated Labour Participation Rate","Region","longitude","latitude"]
sns.lineplot(x="Estimated Labour Participation Rate",y="latitude",data=data2)
# Out:
# <Axes: xlabel='Estimated Labour Participation Rate', ylabel='latitude'>
